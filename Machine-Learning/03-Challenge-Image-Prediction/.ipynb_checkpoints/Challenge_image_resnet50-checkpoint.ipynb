# %% [markdown]
# # Introduction
#
# ###  Challenge MDI341 2019
#
#
# The goal of this challenge is to develop a binary classification system which tries to detect if an **image contains some property not** (you can try to discover what these "properties" are).
#
# As opposed to the previous challenge, we will follow a different procedure in this challenge. The challenge will have **two phases**. Please read the below information carefully.
#
# **In the first phase** of the challenge, you will be provided a **training dataset** which contains the **raw images** and their corresponding **labels**. We will also provide you a **validation dataset**, which only contains the **raw images**. The labes of the validation set will not be provided. In this phase, you will train your system based on this data and the ranking in the challenge webpage will be based on your score obtained on the validation data.
#
# **The second phase** of the challenge will start only **a few hours (at most one day) before the deadline**. Within this period, we will provide you the **test set**. You will need to run the algorithm that you developed on the first phase on this dataset and submit your predictions to the challenge webpage. Your **final ranks** will be determined on this dataset. Note that **this phase will only last a few hours**, which means that you will not be able to tune your algorithm on this dataset.
#
#
#
# ## The properties of the dataset:
#
# **Training data:**
#
# The training set contains raw images and their labels. There are 116157 images in this dataset. Each image is of size 56 x 56 x 3 (the last dimension encodes the color information: red-green-blue). For each image there is a label, either 0 or 1.
#
# **Validation data:**
#
# The validation set only contains raw images. There are 27013 images in this dataset, where the image format is the same as before. The labels of this dataset will not be provided. Within the first phase, your ranks will be calculated based on this dataset.
#
#
# **Test data:**
#
# The test set only contains raw images as well. There will be 59429 images in this dataset, where the image format is the same as before. The labels of this dataset will not be provided either. This dataset will be provided only in the second phase: only a couple of hours before the challenge deadline. Your final ranks will be calculated based on this dataset.
#
#
#
# ### The performance criterion
#
# As you will observe after examining the dataset, the data is highly unbalanced. Therefore, we choose a suitable criterion for evaluation: the performance criterion will be the average accuracy for each class, which is computed as follows:
#
#
# $\text{score} = \frac1{2} \Biggl( \frac1{N_0}\sum_{i=1}^{N} (1-y_i)(1-\hat{y}_i) + \frac1{N_1}\sum_{i=1}^{N} y_i \hat{y}_i \Biggr),$
#
# where $N$ denotes the total number elements of the dataset (it could be the training, validation or test set), $N_0$ denotes the number of elements whose labels are $0$, $N_1$ similarly denotes the number of elements whose labels are $1$, $y_i$ denotes the true label of the data sample $i$, and $\hat{y}_i$ denotes the predicted label for the data sample $i$.
#
#
# As an example, if all your predictions are 0, then your score will be 50%. The higher the score, the better the performance.
#
#
#
# # Training Data
#
# Images: https://www.dropbox.com/s/486li09u91zyjdm/db_train.raw
#
# Labels: https://www.dropbox.com/s/d2hsorvtla3rtf9/label_2019_train.txt
#
#
# # Validation Data
#
# Images: https://www.dropbox.com/s/qonk627t2557utz/db_val.raw

# %% [markdown]
# # Import Data

# %%
# Download data from dropbox:
# !wget https://www.dropbox.com/s/486li09u91zyjdm/db_train.raw
# !wget https://www.dropbox.com/s/d2hsorvtla3rtf9/label_2019_train.txt
# !wget https://www.dropbox.com/s/mnido8qbwmbi79h/db_test.raw
# Out:
# --2019-04-07 18:05:30--  https://www.dropbox.com/s/486li09u91zyjdm/db_train.raw
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.8.1, 2620:100:6018:1::a27d:301
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.8.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/486li09u91zyjdm/db_train.raw [following]
# --2019-04-07 18:05:30--  https://www.dropbox.com/s/raw/486li09u91zyjdm/db_train.raw
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc8c9ef18fd8c09d089b00f2e9c7.dl.dropboxusercontent.com/cd/0/inline/AennKfptSIY-oZpwss368vyuTJuYK3LxvKp_PtV0p9rTnUDLthoJLf4HBM_4DeAj1vKNBPoiHUZBBNOvGp8oLWTIbzwPHTyu2MbK34Gk3W9gALd-bJz1y0Qwswn20_SmU3U/file# [following]
# ...

# %% [markdown]
# # Import Packages

# %%
# from google.colab import drive, files
# drive.mount('/content/gdrive')

# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
import pandas as pd
import os
import glob
import gc

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.optimizers import Adamax, SGD
from tensorflow.keras.layers import Dense, Activation, Embedding, Dropout, Input, Reshape, Lambda, RepeatVector, Flatten
from tensorflow.keras.layers import Flatten, GlobalAveragePooling2D, MaxPooling1D, MaxPooling2D, GlobalAveragePooling1D
from tensorflow.keras import Model
from tensorflow.keras import backend as K
from tensorflow.keras import callbacks
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier

# import Resnet50 from Keras
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input

# %% [markdown]
# # Preamble

# %% [markdown]
# In this challenge I decided to use the ResNet50 known to be a really effective model for image learning. But at the end of the challenge and after many tries I found out that the ResNet50 was too complex for our data and tended to overfit a lot. A simpler structure would be more efficient. However with some tuning as a good learning rate and earlystopping and some predictions ensembling I succeed a not so bad score of 0.839.
#
# NB: During the challenge I made a lot of different models and predictions that I didn't mention in this notebook because it didn't seem relevent to me. I used the bests of those predictions for the ensembling method.

# %% [markdown]
# # Loading and investigating the data

# %% [markdown]
# Here we reshape the image into a tensor (56,56,3) to be used in the ResNet.
# And we reshape the Labels into two as it's more effective for the learning with ResNet from Keras.

# %%
train_images_fname = 'db_train.raw'
train_labels_fname = 'label_2019_train.txt'
test_images_fname    = 'db_test.raw'

# number of images
num_train_images = 116157
num_test_images = 59429

# size of the images 56*56 pixels in gray levels
image_dim = 56 * 56 * 3

# load train labels
train_images_label = np.loadtxt(train_labels_fname, dtype=np.int)

# reshape labels into 2 columns instead of 1
y = np.zeros((num_train_images,2))
y[train_images_label==0,0]=1
y[train_images_label==1,1]=1

# load train data
with open(train_images_fname, 'rb') as f:
    train_images_data = np.fromfile(f, dtype=np.uint8, count=num_train_images * image_dim).astype(np.float32)
    train_images_data = train_images_data.reshape(num_train_images,56,56,3)
    f.close()

# load test data
with open(test_images_fname, 'rb') as f:
    test_images_data = np.fromfile(f, dtype=np.uint8, count=num_test_images * image_dim).astype(np.float32)
    test_images_data = test_images_data.reshape(num_test_images,56,56,3)
    f.close()

# saving some memory space
del train_images_label

# %%
# Investigation
print(f"train shape: {train_images_data.shape}")
print(f"labels shape: {y.shape}")
print(f"test shape: {test_images_data.shape}")
# Out:
# train shape: (116157, 56, 56, 3)
# labels shape: (116157, 2)
# test shape: (59429, 56, 56, 3)

# %%
fig, axes = plt.subplots(nrows=6, ncols=6, figsize=(15, 15))
for i, ax in enumerate(axes.flatten()):
    ax.imshow(train_images_data[i].astype(np.uint8))

# %% [markdown]
# As we can see below, the dataset is a little bit unbalanced but not so much

# %%
# Label distribution:
print(pd.Series(y[:,1]).describe()[['mean','min','max','count']])
pd.DataFrame(y[:,1]).hist(density=1)
plt.show()
# Out:
# mean          0.593059
# min           0.000000
# max           1.000000
# count    116157.000000
# dtype: float64

# %%
# Performance measure
def compute_pred_score(y_true, y_pred):
    if(y_true.shape[0] != y_pred.shape[0]):
        raise Exception("y_pred and y_true must have the same size")
    tmp = np.unique(y_pred)
    if(tmp.shape[0] > 2):
        raise("y_pred should only contain 0 and 1")
        
    if(tmp.shape[0] == 1):
        if(tmp[0] != 0 and tmp[0] != 1):
            raise Exception("y_pred should only contain 0 and 1")
    else:
        if(tmp[0] != 0 and tmp[1] != 1):
            raise Exception("y_pred should only contain 0 and 1")
    
    y0 = (y_true == 0)
    y1 = (y_true == 1)
    
    acc1 = np.mean(1-y_pred[y0])
    acc2 = np.mean(y_pred[y1])
    
    return (acc1+acc2)/2

# %% [markdown]
# # Split the data into train and test

# %%
# Split the data based on a stratify strategy and shuffle it:
X_train, X_test, y_train, y_test = train_test_split(train_images_data ,y ,test_size=0.1, 
                                                    random_state=42, stratify=y, shuffle=True)
print(f"X_train shape : {X_train.shape},\
      X_test shape: {X_test.shape},\
      y_train shape : {y_train.shape},\
      y_test shape : {y_test.shape}")

# save some memory space
del train_images_data
gc.collect()
# Out:
# (104541, 56, 56, 3) (11616, 56, 56, 3) (104541, 2) (11616, 2)
# 2808

# %% [markdown]
# # Search for best parameters

# %% [markdown]
# To make a grid search crossvalidation it takes a very long time with the data we have. So here I'll just give an exemple of how it works :

# %%
def create_model(optimizer):
    K.clear_session()
    # import ResNet50:
    model = ResNet50(include_top=True, weights=None, classes=2, input_shape=(56,56,3))
    # Compile the model:
    model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    return model

# Define parameters to test:
param = {'optimizer': ['SGD', 'RMSprop', 'Adamax']}

# Using Sklearn Wrapper for GridSearchCV:
model = KerasClassifier(build_fn=create_model, epochs=20, batch_size=1024, verbose=1)

# Searching for best parameters
grid = GridSearchCV(estimator=model, param_grid=param, cv=2, return_train_score=False, verbose=1)
grid.fit(X_train, y_train, shuffle=True)

# Select the best estimator with best best parameters:
best_estimator = grid.best_estimator_

# %% [markdown]
# # 1st Model : Virgin ResNet50

# %% [markdown]
# Here we are going to use a ResNet50 structure taken from Keras. We drop the weights and keep the Top to fully train the network on our data

# %%
K.clear_session()
# import ResNet50:
model = ResNet50(include_top=True, weights=None, classes=2, input_shape=(56,56,3))
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\sebas\Anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 56, 56, 3)    0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 62, 62, 3)    0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 28, 28, 64)   9472        conv1_pad[0][0]
# ...

# %%
# Load weights from OneDrive: 
# !wget -O "weights.h5" "https://onedrive.live.com/download?cid=34F11AFD9B26EAE2&resid=34F11AFD9B26EAE2%2128671&authkey=AHwPwcrShDQ34m4"

# Load saved weights from GoogleDrive:
weights_saved = 'weights.h5'
path = f'./gdrive/My Drive/models/{weights_saved}'
tpu_model.load_weights(path)

# %%
# Convert to TPU model
tpu_address = 'grpc://' + os.environ['COLAB_TPU_ADDR']
tf.logging.set_verbosity(tf.logging.ERROR)

tpu_model = tf.contrib.tpu.keras_to_tpu_model(
    model,strategy=tf.contrib.tpu.TPUDistributionStrategy(
        tf.contrib.cluster_resolver.TPUClusterResolver(tpu_address)))
# Out:
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.

# %%
# Define a function to decay the learning rate per epoch:
def step_decay(epoch):
    lrate = 0.02/(epoch+1)
    return lrate

# Plot decay : 
dec = [step_decay(i) for i in range(100)]
plt.plot(dec, '.')
plt.show()

# %%
# We define the EarlyStopping to stop training when the validation accuracy doesn't improve for more than 10 epochs. And we keep the best weights found:
earlystop = EarlyStopping(restore_best_weights=True, monitor='val_binary_accuracy', min_delta=0.0001, patience=10, \
                          verbose=1, mode='auto')
lrate = LearningRateScheduler(schedule=step_decay, verbose=True)
callbacks_list = [earlystop, lrate]

# Complile:
tpu_model.compile(loss='binary_crossentropy', optimizer=Adamax(), metrics=['binary_accuracy'])

# Train:
tpu_model.fit(X_train, y_train, 
              callbacks=callbacks_list,
              validation_data=(X_test, y_test),
              shuffle=True,
              epochs=100, 
              batch_size=1024)
# Out:
# Train on 104541 samples, validate on 11616 samples
# Epoch 1/30
# 104541/104541 [==============================] - 789s 8ms/sample - loss: 0.1056 - binary_accuracy: 0.9592 - val_loss: 1.1415 - val_binary_accuracy: 0.7010
# Epoch 2/30
# 104541/104541 [==============================] - 34s 321us/sample - loss: 0.0668 - binary_accuracy: 0.9746 - val_loss: 1.1695 - val_binary_accuracy: 0.7153
# Epoch 3/30
# 104541/104541 [==============================] - 33s 314us/sample - loss: 0.0622 - binary_accuracy: 0.9768 - val_loss: 1.1899 - val_binary_accuracy: 0.7167
# Epoch 4/30
# 104541/104541 [==============================] - 34s 321us/sample - loss: 0.0584 - binary_accuracy: 0.9784 - val_loss: 1.1690 - val_binary_accuracy: 0.7120
# Epoch 5/30
# 104541/104541 [==============================] - 33s 320us/sample - loss: 0.0611 - binary_accuracy: 0.9774 - val_loss: 1.1500 - val_binary_accuracy: 0.7162
# Epoch 6/30
# ...

# %%
# Convert back the model to CPU:
cpu_model = tpu_model.sync_to_cpu()

# Generate the prediction, save & download
y_pred = cpu_model.predict(test_images_data)
np.savetxt("test_pred_resnet50.txt", np.round(y_pred[:,1]), fmt="%d")
files.download("test_pred_resnet50.txt")

# Save weights in GoogleDrive :
tpu_model.save_weights(path, overwrite=True)

# %% [markdown]
# # 2nd Model : Enhanced ResNet50 with Dropout

# %% [markdown]
# As I mentionned before, the ResNet50 tends to overfit our data. For this reason I decided to modify the top by adding dropout layers to prevent overfit. It improves the results a little bit.

# %%
K.clear_session()
# Import ResNet without Top:
base_model = ResNet50(include_top=True, weights=None, classes=2, input_shape=(56,56,3))

# Add dropout:
x = base_model.output
x = Flatten()(x)
x = Dense(2048, activation='relu', name='fc1')(x)
x = Dropout(0.5)(x)
x = Dense(2048, activation='relu', name='fc2')(x)
x = Dropout(0.5)(x)
predictions = Dense(2, activation='softmax', name='predictions')(x)

model = Model(inputs=base_model.input, outputs=predictions)
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 56, 56, 3)    0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 62, 62, 3)    0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 28, 28, 64)   9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 28, 28, 64)   256         conv1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 28, 28, 64)   0           bn_conv1[0][0]
# ...

# %%
# Convert to TPU model
tpu_address = 'grpc://' + os.environ['COLAB_TPU_ADDR']
tf.logging.set_verbosity(tf.logging.ERROR)

tpu_model = tf.contrib.tpu.keras_to_tpu_model(
    model,strategy=tf.contrib.tpu.TPUDistributionStrategy(
        tf.contrib.cluster_resolver.TPUClusterResolver(tpu_address)))

# %%
# We define the EarlyStopping to stop training when the validation accuracy doesn't improve for more than 10 epochs. And we keep the best weights found:
earlystop = EarlyStopping(restore_best_weights=True, monitor='val_binary_accuracy', min_delta=0.0001, patience=10, \
                          verbose=1, mode='auto')
lrate = LearningRateScheduler(schedule=step_decay, verbose=True)
callbacks_list = [earlystop, lrate]

# Complile:
tpu_model.compile(loss='binary_crossentropy', optimizer=Adamax(), metrics=['binary_accuracy'])

# Train:
tpu_model.fit(X_train, y_train, 
              callbacks=callbacks_list,
              validation_data=(X_test, y_test),
              shuffle=True,
              epochs=100, 
              batch_size=1024)

# %%
# Convert back the model to CPU:
cpu_model = tpu_model.sync_to_cpu()

# Generate the prediction, save & download
y_pred = cpu_model.predict(test_images_data)
np.savetxt("test_pred_resnet50.txt", np.round(y_pred[:,1]), fmt="%d")
files.download("test_pred_resnet50.txt")

# Enregistrer dans google drive :
tpu_model.save_weights(path, overwrite=True)

# %% [markdown]
# # Ensembling

# %% [markdown]
# A well know method to improve results for binary classification is the Ensembling method.
# This consists of gathering different predictions and making a majority vote.
# For this, we want the best predictions we have, but with enough differences for the vote to be effective. We'll use a correlation matrix to measure the similarity between predictions.

# %%
idx = []
list_pred = []
ensemble = pd.DataFrame()

# a list of all .txt file in my folder:
list_file = glob.glob('*.txt')

for i, file in enumerate(list_file):
#     rename predictions files:
    os.rename(file, f"pred{i}.txt")
#     define an index of .txt file:
    idx += [f"pred{i}"]
#     convert all .txt files into Dataframe:
    list_pred += [pd.read_csv(f"pred{i}.txt", header=-1)]
#     Concatenate all .txt files:
    ensemble = pd.concat([ensemble, eval(f"list_pred[{i}]")], axis=1, ignore_index=True)
# Rename columns:
ensemble.columns = idx
print(f"Ensemble shape: {ensemble.shape}")
# Out:
# Ensemble shape: (59429, 9)

# %% [markdown]
# As we can see below, the predictions are highly correlated but with enough differences. That's exactly what we want to improve the result by Ensembling

# %%
sns.clustermap(ensemble.corr(), annot=True, center=0.5)

# %%
# Define a threshold:
trh = np.ceil(ensemble.shape[1]/2)

# Making a majority vote based on threshold: 
ensemble_pred = ensemble.sum(1)
ensemble_pred[ensemble_pred<trh]=0
ensemble_pred[ensemble_pred>=trh]=1

# save the prediction:
np.savetxt("ensemble_pred.txt", ensemble_pred.values, fmt="%d")

# %%
# Prediction distribution: 
ensemble_pred.hist(density=1)
plt.show()

# %% [markdown]
# # Conclusion

# %% [markdown]
# In conclusion, we note that ResNet tends to overfitter but ensembling can reduce this problem very effectively (+ 3% accuracy).
# We could also have built a simpler model with more DropOut or BatchNorm to limit the overfit. But to train a CNN model on so many images and optimize it takes a lot of time and for this reason we can not try everything.
